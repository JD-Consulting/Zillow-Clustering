# %% [markdown]
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

from acquire import acquire_data
from prepare import the_master_imputer, data_prep, percent_of_values_missing, change_data_to_int, change_data_to_object, zillow_single_unit_prop
from set_counties import create_county_cols
from summerize import summarize_data, show_distribution
from preprocessing import split_my_data, scale_data

# %% [markdown]
# # Acquire

# %% [markdown]
# - using our function from our acquire.py file to import our data from SQL and import it into a csv, drop the Unnamed column and assign it to a data frame
# - in our SQL query we decided to eliminate all properties that were not a single unit family residential home
# - we also cut some of our outliers by removing any home where their structuretaxvaluedollarcnt was > $1,000,000

# %%
df = acquire_data()
# Out:
# Acquiring data ...
#
# - csv already exist
#
# Data has been acquired

# %% [markdown]
# # Prepare

# %% [markdown]
# **more outlier control**
#
# - this function below, limits our result's to include homes where the unit's square footage is no less than 500 sq ft, and no less than 1 bedroom and 1 bathroom

# %%
df = zillow_single_unit_prop(df)

# %% [markdown]
# - our data_prep function removes any column missing 50% or more of their data as well as any row missing up to 75% of it's data (*We didn't want to waste time strategizing ways to accuratly sum up data missing over 50% of it's values*)

# %%
df = data_prep(df)

# %% [markdown]
# - the function below tells us what percent of each column is missing

# %%
percent_of_values_missing(df)
# Out:
# parcelid                        0.00
# logerror                        0.00
# transactiondate                 0.00
# bathroomcnt                     0.00
# bedroomcnt                      0.00
# calculatedfinishedsquarefeet    0.00
# fips                            0.00
# latitude                        0.00
# longitude                       0.00
# lotsizesquarefeet               0.62
# regionidcity                    1.96
# regionidcounty                  0.00
# regionidzip                     0.04
# yearbuilt                       0.06
# structuretaxvaluedollarcnt      0.00
# taxvaluedollarcnt               0.00
# landtaxvaluedollarcnt           0.00
# taxamount                       0.01
# dtype: float64

# %% [markdown]
# - using the_master_imputer function, we will fill all of our missing functions with the median value, for that column's rows (*Since we weren't missing more than 2% of any data, we felt that the median would suffice for the missing values in our dataset*)

# %%
df = the_master_imputer(df)

# %% [markdown]
# We see that all of our missing values are taken care of

# %%
df.isna().sum()
# Out:
# parcelid                        0
# logerror                        0
# transactiondate                 0
# bathroomcnt                     0
# bedroomcnt                      0
# calculatedfinishedsquarefeet    0
# fips                            0
# latitude                        0
# longitude                       0
# lotsizesquarefeet               0
# regionidcity                    0
# regionidcounty                  0
# regionidzip                     0
# yearbuilt                       0
# structuretaxvaluedollarcnt      0
# taxvaluedollarcnt               0
# landtaxvaluedollarcnt           0
# taxamount                       0
# dtype: int64

# %% [markdown]
# >now we're going to take our fips # and use that to impute what county our observations were made in using our create_county_cols function and in the process we're going to drop our fips & our regioncounty columns.
# fips source: [THIS LINK](https://www.nrcs.usda.gov/wps/portal/nrcs/detail/?cid=nrcs143_013697)

# %%
df = create_county_cols(df)

# %% [markdown]
# ### Lets change our values so we can have less noise in our exploration / modeling phase

# %% [markdown]
# - using our change_data_to_object function to change the datatypes of *parcelid*, *regionidcity*, *regionidcounty*, *fips* & *regionidzip* to object. (we dont want to do any addition with our unit id's)

# %%
cols = ['yearbuilt', 'latitude', 'longitude', 'lotsizesquarefeet', 'calculatedfinishedsquarefeet', 'bedroomcnt', 'fips' ]
df = change_data_to_int(df, cols)

# %% [markdown]
# - using our change_data_to_int function to change the datatypes of *yearbuilt*, *latitude*, *longitude*, *lotsizesquarefeet*, *calculatedfinishedsquarefeet*, & *bedroomcnt* to change these datatypes from float's to integers to make the data more exclusive

# %%
cols = ['parcelid', 'regionidzip', 'regionidcity', 'LA', 'Ventura', 'Orange', 'fips', 'regionidcounty']
df = change_data_to_object(df, cols)

# %% [markdown]
# ### We're going summarize what our data looks like
# - this functions runs a .info, a .describe and a .shape on our data and returns it in a pandas series

# %%
summarize_data(df)
# Out:
# ******** Info
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51377 entries, 0 to 51585
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   logerror                      51377 non-null  float64
#  1   transactiondate               51377 non-null  object
#  2   bathroomcnt                   51377 non-null  float64
#  3   structuretaxvaluedollarcnt    51377 non-null  float64
#  4   taxvaluedollarcnt             51377 non-null  float64
#  5   landtaxvaluedollarcnt         51377 non-null  float64
#  6   taxamount                     51377 non-null  float64
#  7   county                        51377 non-null  object
#  8   yearbuilt                     51377 non-null  int64
#  9   latitude                      51377 non-null  int64
#  10  longitude                     51377 non-null  int64
#  11  lotsizesquarefeet             51377 non-null  int64
#  12  calculatedfinishedsquarefeet  51377 non-null  int64
#  13  bedroomcnt                    51377 non-null  int64
#  14  parcelid                      51377 non-null  object
#  15  regionidzip                   51377 non-null  object
#  16  regionidcity                  51377 non-null  object
#  17  LA                            51377 non-null  object
#  18  Ventura                       51377 non-null  object
#  19  Orange                        51377 non-null  object
#  20  fips                          51377 non-null  object
#  21  regionidcounty                51377 non-null  object
# dtypes: float64(6), int64(6), object(10)
# memory usage: 9.0+ MB
#
# ******** Shape (51377, 22)
#
# ******** Describe
# <bound method NDFrame.describe of        logerror transactiondate  bathroomcnt  structuretaxvaluedollarcnt  \
# 0      0.025595      2017-01-01          3.5                    485713.0
# 1      0.055619      2017-01-01          1.0                     88000.0
# 2      0.005383      2017-01-01          2.0                     85289.0
# 3     -0.103410      2017-01-01          3.0                    108918.0
# 4     -0.001011      2017-01-01          3.0                    276684.0
# ...         ...             ...          ...                         ...
# 51581  0.020615      2017-09-20          2.0                     70917.0
# 51582  0.013209      2017-09-21          2.0                     50683.0
# 51583  0.037129      2017-09-21          1.0                     32797.0
# 51584  0.007204      2017-09-25          2.0                    140000.0
# 51585 -0.197755      2018-05-25          2.0                     77118.0
#
#        taxvaluedollarcnt  landtaxvaluedollarcnt  taxamount       county  \
# 0              1023282.0               537569.0   11013.72       Orange
# 1               464000.0               376000.0    5672.48      Ventura
# 2               564778.0               479489.0    6488.30       Orange
# 3               145143.0                36225.0    1777.51  Los Angelas
# 4               773303.0               496619.0    9516.26  Los Angelas
# ...                  ...                    ...        ...          ...
# 51581           354621.0               283704.0    4478.43  Los Angelas
# 51582            67205.0                16522.0    1107.48      Ventura
# 51583            49546.0                16749.0     876.43  Los Angelas
# 51584           522000.0               382000.0    6317.15  Los Angelas
# 51585           259334.0               182216.0    3345.78  Los Angelas
#
#        yearbuilt  latitude  ...  calculatedfinishedsquarefeet  bedroomcnt  \
# 0           1998  33634931  ...                          3100           4
# 1           1967  34449266  ...                          1465           2
# 2           1962  33886168  ...                          1243           3
# 3           1970  34245180  ...                          2376           4
# 4           1950  34145202  ...                          2962           4
# ...          ...       ...  ...                           ...         ...
# 51581       1940  34245368  ...                          1286           2
# 51582       1964  34300140  ...                          1612           4
# 51583       1954  34040895  ...                          1032           3
# 51584       1955  33937685  ...                          1762           3
# 51585       1960  34010864  ...                          1050           3
#
#        parcelid  regionidzip regionidcity LA Ventura Orange  fips  \
# 0      14297519        96978        53571  0       0      1  6059
# 1      17052889        97099        13091  0       1      0  6111
# 2      14186244        97078        21412  0       0      1  6059
# 3      12177905        96330       396551  1       0      0  6037
# 4      12095076        96293        47019  1       0      0  6037
# ...         ...          ...          ... ..     ...    ...   ...
# 51581  11000655        96284        12447  1       0      0  6037
# 51582  17239384        97116        27110  0       1      0  6111
# 51583  12773139        96480        36502  1       0      0  6037
# 51584  12826780        96171        14634  1       0      0  6037
# 51585  13083743        96488       118217  1       0      0  6037
#
#       regionidcounty
# 0               1286
# 1               2061
# 2               1286
# 3               3101
# 4               3101
# ...              ...
# 51581           3101
# 51582           2061
# 51583           3101
# 51584           3101
# 51585           3101
#
# [51377 rows x 22 columns]>
#
# ******** Value Counts
# (-0.688, 0.304]    49956
# (0.304, 1.296]      1171
# (-1.68, -0.688]       98
# (1.296, 2.287]        74
# (2.287, 3.279]        49
#                    ...
# 6059               13858
# 6111                4327
# 3101.0             33192
# 1286.0             13858
# 2061.0              4327
# Length: 52208, dtype: int64

# %%
df.describe()
# Out:
#            logerror   bathroomcnt  structuretaxvaluedollarcnt  \
# count  51377.000000  51377.000000                51377.000000
# mean       0.017715      2.261547               175356.551725
# std        0.173323      0.931872               151204.249558
# min       -4.655420      1.000000                  148.000000
# 25%       -0.024559      2.000000                76539.000000
# 50%        0.006746      2.000000               130013.000000
# 75%        0.039774      3.000000               219715.000000
# max        5.262999     10.000000               999140.000000
#
#        taxvaluedollarcnt  landtaxvaluedollarcnt      taxamount     yearbuilt  \
# count       5.137700e+04           5.137700e+04   51377.000000  51377.000000
# mean        4.754713e+05           3.001148e+05    5822.438304   1963.138836
# std         4.589476e+05           3.585572e+05    5285.886480     22.856909
# min         3.254000e+03           1.610000e+02      49.180000   1878.000000
# 25%         1.914510e+05           7.383600e+04    2631.590000   1950.000000
# 50%         3.683750e+05           2.136120e+05    4588.505000   1960.000000
# 75%         6.010000e+05           3.970250e+05    7183.460000   1978.000000
# max         1.087391e+07           1.054104e+07  129365.370000   2016.000000
#
#            latitude     longitude  lotsizesquarefeet  \
# count  5.137700e+04  5.137700e+04       5.137700e+04
# mean   3.402375e+07 -1.181927e+08       1.095165e+04
# std    2.746125e+05  3.562389e+05       8.689483e+04
# min    3.334062e+07 -1.194754e+08       2.360000e+02
# 25%    3.382712e+07 -1.183974e+08       5.578000e+03
# 50%    3.402162e+07 -1.181506e+08       6.800000e+03
# 75%    3.418916e+07 -1.179296e+08       8.636000e+03
# max    3.481877e+07 -1.175546e+08       6.971010e+06
#
#        calculatedfinishedsquarefeet    bedroomcnt
# count                  51377.000000  51377.000000
# mean                    1870.114818      3.291882
# std                      853.040433      0.909385
# min                      501.000000      1.000000
# 25%                     1264.000000      3.000000
# 50%                     1648.000000      3.000000
# 75%                     2271.000000      4.000000
# max                     7970.000000     11.000000

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# - using split_my_data function to split our data into train, test and validate data frames

# %%
train, test, val = split_my_data(df, .15, .50)

# %% [markdown]
# # Exploration

# %% [markdown]
# - Perform clustering with logerror, longitude & latitude

# %%
X = train[['logerror', 'longitude', 'latitude']]

kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
kmeans.predict(X)

train['log_cluster'] = kmeans.predict(X)

# %%
sns.scatterplot(x='longitude', y='latitude' , hue='log_cluster', data=train)

# %% [markdown]
# - 3 distinct clusters of areas found using longitude and latitude
# - lets find out if they're correlated with our counties by visualizing our longitude, latitude and hue it by county

# %%
sns.scatterplot('longitude', 'latitude', hue='county', data=train)

# %% [markdown]
# - visually looks incredibly similar.
# - tells us that their logerror algorithm is dependent on where a home is located

# %%
train.head()
# Out:
#        logerror transactiondate  bathroomcnt  structuretaxvaluedollarcnt  \
# 230    0.090921      2017-01-03          2.0                    101849.0
# 37011  0.188178      2017-07-10          1.5                    226335.0
# 19770  0.044840      2017-04-26          2.0                    151204.0
# 50681 -0.040180      2017-09-13          2.5                    458083.0
# 37426 -0.060420      2017-07-12          2.0                    138074.0
#
#        taxvaluedollarcnt  landtaxvaluedollarcnt  taxamount       county  \
# 230             169738.0                67889.0    2082.42  Los Angelas
# 37011           452670.0               226335.0    4848.08      Ventura
# 19770           431859.0               280655.0    5083.76      Ventura
# 50681          1053673.0               595590.0   12137.42       Orange
# 37426           172592.0                34518.0    2966.29  Los Angelas
#
#        yearbuilt  latitude  ...  bedroomcnt  parcelid  regionidzip  \
# 230         1951  34181933  ...           3  10783039        96364
# 37011       1962  34195133  ...           3  17282217        96383
# 19770       1970  34276636  ...           4  17260896        97116
# 50681       1992  33888911  ...           4  14200286        97079
# 37426       1992  34673952  ...           3  11312167        97318
#
#        regionidcity LA Ventura Orange  fips regionidcounty log_cluster
# 230           12447  1       0      0  6037           3101           2
# 37011         34278  0       1      0  6111           2061           0
# 19770         27110  0       1      0  6111           2061           0
# 50681         21412  0       0      1  6059           1286           1
# 37426          5534  1       0      0  6037           3101           2
#
# [5 rows x 23 columns]

# %%
X = train[['logerror', 'calculatedfinishedsquarefeet']]

kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
kmeans.predict(X)

train['sqft_cluster'] = kmeans.predict(X)

# %%
sns.scatterplot('calculatedfinishedsquarefeet', 'logerror', hue='sqft_cluster', data=train)

# %%
with plt.style.context('seaborn-whitegrid'):
    plt.figure(figsize=(9, 6))
    pd.Series({k: KMeans(k).fit(X).inertia_ for k in range(2, 12)}).plot(marker='x')
    plt.xticks(range(2, 12))
    plt.xlabel('k')
    plt.ylabel('inertia')
    plt.title('Change in inertia as k increases')

# %% [markdown]
# - looks like the optimal k value would be about 5

# %%
X = train[['logerror', 'calculatedfinishedsquarefeet']]

kmeans = KMeans(n_clusters=5)
kmeans.fit(X)
kmeans.predict(X)

train['sqft_cluster'] = kmeans.predict(X)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot('calculatedfinishedsquarefeet', 'logerror', hue='sqft_cluster', data=train)

# %%
X = train[['logerror', 'yearbuilt']]

kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
kmeans.predict(X)

train['yearbuilt_cluster'] = kmeans.predict(X)

# %%
sns.scatterplot('yearbuilt', 'logerror', hue='yearbuilt_cluster', data=train)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43670 entries, 230 to 49888
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   logerror                      43670 non-null  float64
#  1   transactiondate               43670 non-null  object
#  2   bathroomcnt                   43670 non-null  float64
#  3   structuretaxvaluedollarcnt    43670 non-null  float64
#  4   taxvaluedollarcnt             43670 non-null  float64
#  5   landtaxvaluedollarcnt         43670 non-null  float64
#  6   taxamount                     43670 non-null  float64
#  7   county                        43670 non-null  object
#  8   yearbuilt                     43670 non-null  int64
#  9   latitude                      43670 non-null  int64
#  10  longitude                     43670 non-null  int64
#  11  lotsizesquarefeet             43670 non-null  int64
#  12  calculatedfinishedsquarefeet  43670 non-null  int64
#  13  bedroomcnt                    43670 non-null  int64
#  14  parcelid                      43670 non-null  object
#  15  regionidzip                   43670 non-null  object
#  16  regionidcity                  43670 non-null  object
#  17  LA                            43670 non-null  object
#  18  Ventura                       43670 non-null  object
#  19  Orange                        43670 non-null  object
#  20  fips                          43670 non-null  object
#  21  regionidcounty                43670 non-null  object
#  22  log_cluster                   43670 non-null  int32
#  23  sqft_cluster                  43670 non-null  int32
#  24  yearbuilt_cluster             43670 non-null  int32
# dtypes: float64(6), int32(3), int64(6), object(10)
# memory usage: 8.2+ MB

# %%
# 43560

train.lotsizesquarefeet.median()
# Out:
# 6800.0

# %%
sns.scatterplot('logerror','bedroomcnt',  hue='bedcnt_cluster', data=train)
